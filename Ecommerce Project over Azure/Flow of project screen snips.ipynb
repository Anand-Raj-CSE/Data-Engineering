# %% [markdown]
# 1. Data Ingestion from githib and MySQL server hosted and DB created over filess.io , Screen snip from
#     Azure Data factory after creating Data lake storage account and putting the data into Bronze layer
#     following the Medallion architecture.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## published final pipeline over data factory , used lookup for lookup over gihub raw json
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Post debugging the pipeline , all data is present over Azure Data Lake
# ![image.png](attachment:image.png)
